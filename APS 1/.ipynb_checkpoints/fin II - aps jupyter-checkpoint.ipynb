# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()
from scipy import optimize as op

# %% [markdown]
# # Portfólio 1

# %%
#taxa livre de risco
rf=0.0074
#numero de simulações da carteira
num_sim=100000
#base de dados com os retornos de cada ação
carteira=pd.read_excel(r'D:\Insper\Pasta1.xlsx')
#data como índice da tabela
carteira.set_index(['Data'],inplace=True)
#salvando os tickers em uma lista
tickers=list(carteira.columns)
#savando a contagem do número de ações em uma variável
num_acoes=len(tickers)
#tabela que contém a primeira coleção de ativos
carteira
# Out:
#           Retorno IBOVESPA  JBSS3 - JBS  MTZ - MasTec  RIO - Rio Tinto  \
# Data
# Fev-2012          0.043427     0.142410      0.079804        -0.043655
# Mar-2012         -0.019769     0.027397      0.028425        -0.023538
# Abr-2012         -0.041699     0.000000     -0.038695         0.008635
# Mai-2012         -0.118570    -0.273333     -0.059804        -0.229178
# Jun-2012         -0.002496     0.106422     -0.080122         0.106201
# ...                    ...          ...           ...              ...
# Ago-2021         -0.024793     0.004232     -0.096710        -0.069607
# Set-2021         -0.065683     0.189285     -0.056430        -0.109897
# Out-2021         -0.067386     0.053412      0.033032        -0.053128
# Nov-2021         -0.015316    -0.062387      0.034107        -0.009167
# Dez-2021          0.028524     0.064516      0.001193         0.067794
#
#           VIXM - Volatility Index  BTG Pactual Tesouro IPCA  ABEV3 - Ambev  \
# Data
# Fev-2012                 0.002092                  0.017614       0.117692
# Mar-2012                -0.154018                  0.018123       0.098186
# Abr-2012                -0.018421                  0.041829       0.071143
# Mai-2012                 0.109439                  0.022064      -0.071503
# Jun-2012                -0.108594                 -0.004992       0.015305
# ...                           ...                       ...            ...
# Ago-2021                -0.035973                 -0.011043       0.027644
# Set-2021                 0.057610                 -0.001658      -0.105263
# Out-2021                -0.058805                 -0.025613       0.110458
# Nov-2021                 0.079908                  0.034466      -0.054738
# Dez-2021                -0.069123                  0.002006      -0.002379
#
#           BRFS3 - BRF  ELET3 - Eletrobrás  LPSB3 - Lopes Royal  \
# Data
# Fev-2012     0.037572            0.040669             0.084888
# Mar-2012     0.002786           -0.082441             0.061909
# Abr-2012    -0.031944           -0.049008            -0.112011
# Mai-2012    -0.099283           -0.113414             0.138075
# Jun-2012    -0.028187            0.073851            -0.089674
# ...               ...                 ...                  ...
# Ago-2021    -0.085870           -0.065093             0.009456
# Set-2021     0.156704            0.023386            -0.362998
# Out-2021    -0.142488           -0.121527            -0.102941
# Nov-2021    -0.149806           -0.035471            -0.049180
# Dez-2021     0.140253            0.023904            -0.038793
#
#           WY - Weyerhauser  HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII  \
# Data
# Fev-2012          0.050846                                    0.058813
# Mar-2012          0.049306                                   -0.040468
# Abr-2012         -0.071168                                   -0.003907
# Mai-2012         -0.014664                                   -0.072917
# Jun-2012          0.123054                                    0.007262
# ...                    ...                                         ...
# Ago-2021          0.067299                                   -0.034234
# Set-2021         -0.007298                                   -0.035199
# Out-2021          0.018453                                   -0.017849
# Nov-2021          0.052912                                   -0.031599
# Dez-2021          0.099889                                    0.080958
#
#           DIS -Disney  TIP - iShares TIPS Bonds ETF
# Data
# Fev-2012     0.079434                     -0.005781
# Mar-2012     0.042629                     -0.008595
# Abr-2012    -0.015304                      0.017845
# Mai-2012     0.060311                      0.019464
# Jun-2012     0.061037                     -0.006686
# ...               ...                           ...
# Ago-2021     0.029997                     -0.001641
# Set-2021    -0.066906                     -0.007800
# Out-2021    -0.000591                      0.011096
# Nov-2021    -0.142959                      0.008649
# Dez-2021     0.068944                      0.004031
#
# [119 rows x 14 columns]

# %% [markdown]
# # Calculadando o retorno esperado da carteira

# %%
retorno_mensal_esperado=carteira.mean()
retorno_mensal_esperado
# Out:
# Retorno IBOVESPA                              0.006443
# JBSS3 - JBS                                   0.023053
# MTZ - MasTec                                  0.020067
# RIO - Rio Tinto                               0.009163
# VIXM - Volatility Index                      -0.014052
# BTG Pactual Tesouro IPCA                      0.008871
# ABEV3 - Ambev                                 0.008301
# BRFS3 - BRF                                   0.003434
# ELET3 - Eletrobrás                            0.021774
# LPSB3 - Lopes Royal                          -0.003005
# WY - Weyerhauser                              0.012366
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII    0.004833
# DIS -Disney                                   0.014857
# TIP - iShares TIPS Bonds ETF                  0.002319
# dtype: float64

# %% [markdown]
# # Calculando a matriz de covariãncia

# %%
cov_carteira=carteira.cov()
cov_carteira
# Out:
#                                             Retorno IBOVESPA  JBSS3 - JBS  \
# Retorno IBOVESPA                                    0.004216     0.002000
# JBSS3 - JBS                                         0.002000     0.012784
# MTZ - MasTec                                        0.002277     0.002155
# RIO - Rio Tinto                                     0.002594     0.000737
# VIXM - Volatility Index                            -0.003009    -0.001961
# BTG Pactual Tesouro IPCA                            0.000865     0.000179
# ABEV3 - Ambev                                       0.001989     0.001520
# BRFS3 - BRF                                         0.003651     0.005040
# ELET3 - Eletrobrás                                  0.006471     0.005395
# LPSB3 - Lopes Royal                                 0.004876     0.000750
# WY - Weyerhauser                                    0.002510     0.002048
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII          0.003450     0.000734
# DIS -Disney                                         0.001635     0.001785
# TIP - iShares TIPS Bonds ETF                        0.000196     0.000064
#
#                                             MTZ - MasTec  RIO - Rio Tinto  \
# Retorno IBOVESPA                                0.002277         0.002594
# JBSS3 - JBS                                     0.002155         0.000737
# MTZ - MasTec                                    0.010880         0.002152
# RIO - Rio Tinto                                 0.002152         0.006280
# VIXM - Volatility Index                        -0.003426        -0.001830
# BTG Pactual Tesouro IPCA                        0.000299         0.000406
# ABEV3 - Ambev                                   0.001551         0.001272
# BRFS3 - BRF                                     0.002412         0.001321
# ELET3 - Eletrobrás                              0.003197         0.002577
# LPSB3 - Lopes Royal                             0.003795         0.000157
# WY - Weyerhauser                                0.003767         0.001850
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII      0.001695         0.002675
# DIS -Disney                                     0.002663         0.001897
# TIP - iShares TIPS Bonds ETF                   -0.000095         0.000085
#
#                                             VIXM - Volatility Index  \
# Retorno IBOVESPA                                          -0.003009
# JBSS3 - JBS                                               -0.001961
# MTZ - MasTec                                              -0.003426
# RIO - Rio Tinto                                           -0.001830
# VIXM - Volatility Index                                    0.009100
# BTG Pactual Tesouro IPCA                                  -0.000577
# ABEV3 - Ambev                                             -0.002715
# BRFS3 - BRF                                               -0.004007
# ELET3 - Eletrobrás                                        -0.001901
# LPSB3 - Lopes Royal                                       -0.003321
# WY - Weyerhauser                                          -0.004501
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII                -0.002437
# DIS -Disney                                               -0.003262
# TIP - iShares TIPS Bonds ETF                              -0.000162
#
#                                             BTG Pactual Tesouro IPCA  \
# Retorno IBOVESPA                                            0.000865
# JBSS3 - JBS                                                 0.000179
# MTZ - MasTec                                                0.000299
# RIO - Rio Tinto                                             0.000406
# VIXM - Volatility Index                                    -0.000577
# BTG Pactual Tesouro IPCA                                    0.000494
# ABEV3 - Ambev                                               0.000438
# BRFS3 - BRF                                                 0.000482
# ELET3 - Eletrobrás                                          0.001426
# LPSB3 - Lopes Royal                                         0.001287
# WY - Weyerhauser                                            0.000579
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII                  0.000999
# DIS -Disney                                                 0.000275
# TIP - iShares TIPS Bonds ETF                                0.000111
#
#                                             ABEV3 - Ambev  BRFS3 - BRF  \
# Retorno IBOVESPA                                 0.001989     0.003651
# JBSS3 - JBS                                      0.001520     0.005040
# MTZ - MasTec                                     0.001551     0.002412
# RIO - Rio Tinto                                  0.001272     0.001321
# VIXM - Volatility Index                         -0.002715    -0.004007
# BTG Pactual Tesouro IPCA                         0.000438     0.000482
# ABEV3 - Ambev                                    0.004397     0.002811
# BRFS3 - BRF                                      0.002811     0.012639
# ELET3 - Eletrobrás                               0.001720     0.005120
# LPSB3 - Lopes Royal                              0.003412     0.004673
# WY - Weyerhauser                                 0.001503     0.002669
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII       0.001842     0.001931
# DIS -Disney                                      0.001376     0.002773
# TIP - iShares TIPS Bonds ETF                     0.000089     0.000095
#
#                                             ELET3 - Eletrobrás  \
# Retorno IBOVESPA                                      0.006471
# JBSS3 - JBS                                           0.005395
# MTZ - MasTec                                          0.003197
# RIO - Rio Tinto                                       0.002577
# VIXM - Volatility Index                              -0.001901
# BTG Pactual Tesouro IPCA                              0.001426
# ABEV3 - Ambev                                         0.001720
# BRFS3 - BRF                                           0.005120
# ELET3 - Eletrobrás                                    0.027738
# LPSB3 - Lopes Royal                                   0.009956
# WY - Weyerhauser                                      0.002601
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII            0.005928
# DIS -Disney                                           0.000920
# TIP - iShares TIPS Bonds ETF                          0.000209
#
#                                             LPSB3 - Lopes Royal  \
# Retorno IBOVESPA                                       0.004876
# JBSS3 - JBS                                            0.000750
# MTZ - MasTec                                           0.003795
# RIO - Rio Tinto                                        0.000157
# VIXM - Volatility Index                               -0.003321
# BTG Pactual Tesouro IPCA                               0.001287
# ABEV3 - Ambev                                          0.003412
# BRFS3 - BRF                                            0.004673
# ELET3 - Eletrobrás                                     0.009956
# LPSB3 - Lopes Royal                                    0.025311
# WY - Weyerhauser                                       0.001345
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII             0.004885
# DIS -Disney                                            0.001341
# TIP - iShares TIPS Bonds ETF                           0.000334
#
#                                             WY - Weyerhauser  \
# Retorno IBOVESPA                                    0.002510
# JBSS3 - JBS                                         0.002048
# MTZ - MasTec                                        0.003767
# RIO - Rio Tinto                                     0.001850
# VIXM - Volatility Index                            -0.004501
# BTG Pactual Tesouro IPCA                            0.000579
# ABEV3 - Ambev                                       0.001503
# BRFS3 - BRF                                         0.002669
# ELET3 - Eletrobrás                                  0.002601
# LPSB3 - Lopes Royal                                 0.001345
# WY - Weyerhauser                                    0.006631
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII          0.002434
# DIS -Disney                                         0.002470
# TIP - iShares TIPS Bonds ETF                        0.000263
#
#                                             HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII  \
# Retorno IBOVESPA                                                              0.003450
# JBSS3 - JBS                                                                   0.000734
# MTZ - MasTec                                                                  0.001695
# RIO - Rio Tinto                                                               0.002675
# VIXM - Volatility Index                                                      -0.002437
# BTG Pactual Tesouro IPCA                                                      0.000999
# ABEV3 - Ambev                                                                 0.001842
# BRFS3 - BRF                                                                   0.001931
# ELET3 - Eletrobrás                                                            0.005928
# LPSB3 - Lopes Royal                                                           0.004885
# WY - Weyerhauser                                                              0.002434
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII                                    0.006291
# DIS -Disney                                                                   0.001682
# TIP - iShares TIPS Bonds ETF                                                  0.000260
#
#                                             DIS -Disney  \
# Retorno IBOVESPA                               0.001635
# JBSS3 - JBS                                    0.001785
# MTZ - MasTec                                   0.002663
# RIO - Rio Tinto                                0.001897
# VIXM - Volatility Index                       -0.003262
# BTG Pactual Tesouro IPCA                       0.000275
# ABEV3 - Ambev                                  0.001376
# BRFS3 - BRF                                    0.002773
# ELET3 - Eletrobrás                             0.000920
# LPSB3 - Lopes Royal                            0.001341
# WY - Weyerhauser                               0.002470
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII     0.001682
# DIS -Disney                                    0.004625
# TIP - iShares TIPS Bonds ETF                   0.000041
#
#                                             TIP - iShares TIPS Bonds ETF
# Retorno IBOVESPA                                                0.000196
# JBSS3 - JBS                                                     0.000064
# MTZ - MasTec                                                   -0.000095
# RIO - Rio Tinto                                                 0.000085
# VIXM - Volatility Index                                        -0.000162
# BTG Pactual Tesouro IPCA                                        0.000111
# ABEV3 - Ambev                                                   0.000089
# BRFS3 - BRF                                                     0.000095
# ELET3 - Eletrobrás                                              0.000209
# LPSB3 - Lopes Royal                                             0.000334
# WY - Weyerhauser                                                0.000263
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII                      0.000260
# DIS -Disney                                                     0.000041
# TIP - iShares TIPS Bonds ETF                                    0.000152

# %% [markdown]
# # Criando listas para salvar os pesos, o retorno , o desvio padão e o índice de sharpe da simulação das carteiras e simulando carteiras

# %%
peso_acoes=[]
retorno_cart=[]
desvio_cart=[]
sharpe_index=[]
for carteiras in range(num_sim):
    #criando um vetor randõmicos de números, com 15 posições
    a=-1
    b=1
    peso=(b-a)*np.random.random(num_acoes)+a
    #determinando o peso representativo de cada ativo, para isso divimos cada peso pela soma do vetor pela soma de todos
    peso=peso/np.sum(peso)
    #calculando o retorno da carteira multiplicando o peso dos ativos pelo retorno de cada um
    retorno=np.dot(peso,retorno_mensal_esperado)
    #desvio padrão da carteira: multiplicando a matriz de pesos pela matriz de covariância e em sequência multiplica-se o resultado pela matiz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T,np.matmul(peso,np.array(cov_carteira))))
    #calculando o índice de sharpe para a carteira, já considerando o ativo livre de risco rf
    sharpe=(retorno-rf)/desvio
    #salvando as informações nas listas criadas anteriormente
    peso_acoes.append(peso)
    retorno_cart.append(retorno)
    desvio_cart.append(desvio)
    sharpe_index.append(sharpe)

# %% [markdown]
# # Criando um data frame com as informações de cada carteira aleatória gerada anteriormente;peso, retorno, desvio e o sharpe

# %%
dicionario={'Retorno':retorno_cart,'Desvio Padrão': desvio_cart,'Sharpe': sharpe_index}

# %%
for counter,ticker in enumerate(tickers):
    dicionario[ticker + ' peso'] = [peso[counter] for peso in peso_acoes]
    carteira2 = pd.DataFrame(dicionario)

carteira2
# Out:
#         Retorno  Desvio Padrão    Sharpe  Retorno IBOVESPA peso  \
# 0      0.004236       0.168701 -0.018754               0.101984
# 1     -0.009924       0.164472 -0.105332               0.564266
# 2     -0.008283       0.092232 -0.170039              -0.071270
# 3      0.028446       0.209798  0.100315              -0.181371
# 4      0.011262       0.070640  0.054675              -0.026747
# ...         ...            ...       ...                    ...
# 99995  0.006522       0.049286 -0.017811              -0.048150
# 99996  0.008268       0.097281  0.008926               0.366864
# 99997  0.008342       0.095190  0.009899              -0.421049
# 99998  0.137310       1.693781  0.076699               4.249667
# 99999  0.004356       0.082844 -0.036749               0.171046
#
#        JBSS3 - JBS peso  MTZ - MasTec peso  RIO - Rio Tinto peso  \
# 0              0.339235          -0.483970             -0.315345
# 1              0.822790          -0.630666              0.691330
# 2             -0.399705          -0.314874              0.497253
# 3             -0.532907           0.629333             -0.594626
# 4              0.183044           0.322014             -0.231658
# ...                 ...                ...                   ...
# 99995          0.144695          -0.192508              0.114972
# 99996          0.154400           0.009268             -0.102618
# 99997          0.281465          -0.406241              0.143443
# 99998          4.517219           7.034611              9.689627
# 99999         -0.275451           0.379282              0.197402
#
#        VIXM - Volatility Index peso  BTG Pactual Tesouro IPCA peso  \
# 0                          0.006029                       0.172240
# 1                          0.633964                      -0.926708
# 2                          0.331544                       0.393110
# 3                         -0.795758                       0.719042
# 4                          0.418191                       0.403727
# ...                             ...                            ...
# 99995                      0.134653                       0.134345
# 99996                      0.114365                       0.111553
# 99997                     -0.078770                       0.245299
# 99998                     -2.424052                       6.653396
# 99999                      0.117677                       0.348390
#
#        ABEV3 - Ambev peso  BRFS3 - BRF peso  ELET3 - Eletrobrás peso  \
# 0                0.135840          0.499253                 0.402131
# 1               -0.870342         -0.844754                -0.536120
# 2               -0.152007          0.103691                 0.240779
# 3               -0.493006          0.850504                -0.210715
# 4                0.139912         -0.330560                 0.173354
# ...                   ...               ...                      ...
# 99995            0.172592          0.165267                 0.112238
# 99996           -0.307167         -0.072509                 0.278126
# 99997            0.347268          0.181481                 0.319865
# 99998           -8.374714         -4.553969                -8.142122
# 99999            0.203331         -0.387690                -0.179140
#
#        LPSB3 - Lopes Royal peso  WY - Weyerhauser peso  \
# 0                      0.516136              -0.560098
# 1                      0.189261               0.853037
# 2                     -0.090343               0.171838
# 3                     -0.311882               0.842369
# 4                     -0.224170              -0.110020
# ...                         ...                    ...
# 99995                  0.037080               0.185893
# 99996                  0.223475               0.302677
# 99997                  0.270858               0.440418
# 99998                  5.514329              -3.071099
# 99999                 -0.142030               0.185378
#
#        HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII peso  DIS -Disney peso  \
# 0                                             0.002691          0.267732
# 1                                             0.741547         -0.124926
# 2                                             0.339896         -0.313978
# 3                                            -0.497627          0.822468
# 4                                             0.073464          0.096966
# ...                                                ...               ...
# 99995                                         0.032723          0.016159
# 99996                                         0.217573         -0.237399
# 99997                                        -0.386790         -0.419399
# 99998                                        -5.225217          2.894558
# 99999                                         0.248403         -0.154609
#
#        TIP - iShares TIPS Bonds ETF peso
# 0                              -0.083859
# 1                               0.437319
# 2                               0.264064
# 3                               0.754177
# 4                               0.112482
# ...                                  ...
# 99995                          -0.009959
# 99996                          -0.058607
# 99997                           0.482152
# 99998                          -7.762234
# 99999                           0.288011
#
# [100000 rows x 17 columns]

# %% [markdown]
# # Plotando o sharpe de todas as carteiras simuladas em gráfico de retorno por desvio padrão

# %%
carteira2.plot.scatter(x='Desvio Padrão', y='Retorno', c='Sharpe', figsize=(16,8), grid = True, cmap='RdYlGn', edgecolors= 'black', xlim=(0,0.2), ylim=(-0.05,0.05))

# %% [markdown]
# # Localizando a carteira com maior sharpe

# %%
maior_sharpe= carteira2['Sharpe'].max()
carteira_maior_sharpe=carteira2.loc[carteira2['Sharpe']==maior_sharpe]
#aqui pegamos a matriz transposta para ter uma melhor vizualização dos dados
print(f'carteira com maior sharpe: {carteira_maior_sharpe.T}')
# Out:
# carteira com maior sharpe:                                                      7322
# Retorno                                          0.115063
# Desvio Padrão                                    0.335631
# Sharpe                                           0.320778
# Retorno IBOVESPA peso                           -0.764217
# JBSS3 - JBS peso                                 1.450482
# MTZ - MasTec peso                                1.262446
# RIO - Rio Tinto peso                             0.146077
# VIXM - Volatility Index peso                    -1.260562
# BTG Pactual Tesouro IPCA peso                    1.578389
# ABEV3 - Ambev peso                               0.835104
# BRFS3 - BRF peso                                -0.513207
# ELET3 - Eletrobrás peso                          0.995300
# LPSB3 - Lopes Royal peso                        -1.163974
# WY - Weyerhauser peso                           -0.664249
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII peso -0.732288
# DIS -Disney peso                                 0.795029
# TIP - iShares TIPS Bonds ETF peso               -0.964328

# %% [markdown]
# # Criando a função de otimização, de soma dos pesos e encontrando a carteira otima a partir da biblioteca optimize

# %%
def otimizacao(peso, retorno_mesnsal_esperado, cov_carteira, rf):
    #primeiro calculamos o retorno da carteira multiplicando a matriz do peso pela matriz dos retornos esperados
    retorno= np.dot(peso, retorno_mensal_esperado)
    #segundo passo é calcular o desvio padrão da carteira, para isso multiplicamos a matriz de pesos pela matriz de covariãncias e multiplicamos esse resultado pela matriz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T, np.matmul(peso,np.array(cov_carteira))))
    #por fim calculamos o sharpe já considerando o ativo livre de riscos rf
    sharpe=-(retorno-rf)/desvio
    
    return sharpe

def soma_pesos(peso):
    soma=1
    soma=soma - np.sum(peso)
    return soma

restricao= {'type': 'eq', 'fun': soma_pesos}
start= np.random.random(num_acoes)
args= (retorno_mensal_esperado, cov_carteira, rf)
result= op.minimize(otimizacao, start, args=args, constraints=restricao)
pesos= result.x
carteiraOtima= pd.DataFrame({'Ativos': tickers, 'Pesos': pesos})
carteiraOtima.set_index(['Ativos'],inplace=True)
carteiraOtima
# Out:
#                                                   Pesos
# Ativos
# Retorno IBOVESPA                           -2049.133253
# JBSS3 - JBS                                  330.561734
# MTZ - MasTec                                 544.819111
# RIO - Rio Tinto                              115.300816
# VIXM - Volatility Index                    -1898.611033
# BTG Pactual Tesouro IPCA                    5860.245331
# ABEV3 - Ambev                                 16.724392
# BRFS3 - BRF                                 -923.167050
# ELET3 - Eletrobrás                           892.866422
# LPSB3 - Lopes Royal                         -556.979659
# WY - Weyerhauser                           -1018.122864
# HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII -1049.691166
# DIS -Disney                                 1059.382785
# TIP - iShares TIPS Bonds ETF               -1323.195565

# %%
#calculando o retorno da carteira multiplicando a matriz peso pela matriz dos retornos esperados
retorno_p= np.dot(pesos, retorno_mensal_esperado)
#calculando o desvio padrão da carteira multiplicando a matriz de pesos pela matriz de covariância e multiplicando esse resultado pela matriz transposta do peso
desvio_p= np.sqrt(np.matmul(pesos.T, np.matmul(pesos, np.array(cov_carteira))))
#calculando o índice de sharpe
sharpe_p= (retorno_p-rf)/desvio_p
pd.DataFrame([retorno_p, desvio_p, sharpe_p], ['E[r]', 'Risco','Sharpe'], ['carteira de ativos de risco otima'])
# Out:
#         carteira de ativos de risco otima
# E[r]                            98.167089
# Risco                          233.584995
# Sharpe                           0.420231

# %% [markdown]
# # Construindo a LAC

# %%
fim= max(carteira2['Desvio Padrão'])
x= np.linspace(0,fim,num_sim)
lac= sharpe_p*x + rf
plt.figure(num="Grafico de retorno por desvio padrão", figsize = (16,8), dpi=80)
plt.scatter(x=carteira2['Desvio Padrão'], y=carteira2['Retorno'], c=carteira2['Sharpe'], s=20, cmap='RdYlGn', edgecolors='black' )
#plt.scatter(x=carteira_sharpe['Desvio Padrão'], y=carteira_sharpe['Retorno'], s=50, edgecolors='black', label='Carteira Otima Otimização')      
plt.scatter(x=desvio_p, y=retorno_p, s=50,edgecolors='black', label='Carteira Otima Otimização')
plt.plot(x,lac,label='LAC')
plt.ylim((-0.12,200))
plt.xlim((0,400))
#plt.yticks(carteira_sharpe['Retorno'])
#plt.xticks(carteira_sharpe['Desvio Padrão'])
#plt.grid()
plt.legend()

# %% [markdown]
# # Criando a função utilidade e plotando o gráfico de cada perfil de investidor junto com a LAC

# %%
def retorno_utilidade_investidor(A, U):
    sigma= np.linspace(0,max(carteira2['Desvio Padrão']), num_sim)
    retorno= 0.5*A*sigma**2 + U
    return retorno

# %%
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
U=0.05
plt.plot(x, retorno_utilidade_investidor(20,U), label='Utilidade Conservador')
plt.plot(x, retorno_utilidade_investidor(10,U), label='Utilidade Moderado')
plt.plot(x, retorno_utilidade_investidor(5,U), label='Utilidade Agressivo')
plt.plot(x,lac,label='LAC')
plt.legend()

# %% [markdown]
# # Criando a função para encontrar o retorno, desvio e utilidade de cada investidor, e em seguida plotando o gráfico de cada um

# %%
def CPO(A):
    y= (retorno_p-rf)/(A*desvio_p**2)
    retorno_c=y*retorno_p + (1-y)*rf
    desvio_c = ((y**2)*desvio_p**2)**(1/2)
    return retorno_c, desvio_c

def utilidade_investidor(A, retorno_c, desvio_c):
    utilidade_c= retorno_c - 0.5*A*desvio_c**2
    return utilidade_c

# %%
A=20
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Conservador')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.1))
plt.xlim((0,0.2))
plt.legend()

# %%
A=10
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Moderado')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.3))
plt.xlim((0,0.3))
plt.legend()

# %%
A=5
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Agressivo')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.1))
plt.xlim((0,0.2))
plt.legend()

# %% [markdown]
# # Portfólio 2

# %%
#taxa livre de risco
rf=0.00177
#numero de simulações da carteira
num_sim=100000
#base de dados com os retornos de cada ação
carteira=pd.read_excel(r'D:\Insper\Pasta2.xlsx')
#data como índice da tabela
carteira.set_index(['Data'],inplace=True)
#salvando os tickers em uma lista
tickers=list(carteira.columns)
#savando a contagem do número de ações em uma variável
num_acoes=len(tickers)
#tabela que contém a primeira coleção de ativos
carteira
# Out:
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBRK.B  \
# Data
# Jan-2012                                           0.027130
# Fev-2012                                           0.001021
# Mar-2012                                           0.034417
# Abr-2012                                          -0.008626
# Mai-2012                                          -0.013549
# ...                                                     ...
# Ago-2021                                           0.026878
# Set-2021                                          -0.044896
# Out-2021                                           0.051550
# Nov-2021                                          -0.035957
# Dez-2021                                           0.080632
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBLK  \
# Data
# Jan-2012                                           0.021095
# Fev-2012                                           0.093407
# Mar-2012                                           0.037498
# Abr-2012                                          -0.065007
# Mai-2012                                          -0.108466
# ...                                                     ...
# Ago-2021                                           0.087780
# Set-2021                                          -0.107041
# Out-2021                                           0.124961
# Nov-2021                                          -0.041178
# Dez-2021                                           0.016773
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nGME  \
# Data
# Jan-2012                                          -0.031910
# Fev-2012                                          -0.018374
# Mar-2012                                          -0.041264
# Abr-2012                                           0.042125
# Mai-2012                                          -0.150616
# ...                                                     ...
# Ago-2021                                           0.354518
# Set-2021                                          -0.195977
# Out-2021                                           0.045820
# Nov-2021                                           0.069206
# Dez-2021                                          -0.243718
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nJPM  \
# Data
# Jan-2012                                           0.129880
# Fev-2012                                           0.052011
# Mar-2012                                           0.171764
# Abr-2012                                          -0.059127
# Mai-2012                                          -0.228711
# ...                                                     ...
# Ago-2021                                           0.053828
# Set-2021                                           0.023382
# Out-2021                                           0.044131
# Nov-2021                                          -0.065101
# Dez-2021                                          -0.003022
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nORCL  \
# Data
# Jan-2012                                           0.102261
# Fev-2012                                           0.037044
# Mar-2012                                          -0.003247
# Abr-2012                                           0.010281
# Mai-2012                                          -0.099660
# ...                                                     ...
# Ago-2021                                           0.022837
# Set-2021                                          -0.022439
# Out-2021                                           0.104944
# Nov-2021                                          -0.054201
# Dez-2021                                          -0.038902
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nPETR4  \
# Data
# Jan-2012                                           0.244648
# Fev-2012                                           0.006726
# Mar-2012                                          -0.094472
# Abr-2012                                          -0.121816
# Mai-2012                                          -0.150743
# ...                                                     ...
# Ago-2021                                           0.066068
# Set-2021                                          -0.053045
# Out-2021                                          -0.035372
# Nov-2021                                           0.084439
# Dez-2021                                           0.093620
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nTSLA  \
# Data
# Jan-2012                                           0.017857
# Fev-2012                                           0.149295
# Mar-2012                                           0.114636
# Abr-2012                                          -0.110365
# Mai-2012                                          -0.109568
# ...                                                     ...
# Ago-2021                                           0.070605
# Set-2021                                           0.054042
# Out-2021                                           0.436530
# Nov-2021                                           0.027612
# Dez-2021                                          -0.076855
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVALE3  \
# Data
# Jan-2012                                           0.222144
# Fev-2012                                          -0.008684
# Mar-2012                                          -0.075962
# Abr-2012                                          -0.019508
# Mai-2012                                          -0.174547
# ...                                                     ...
# Ago-2021                                          -0.096509
# Set-2021                                          -0.193572
# Out-2021                                          -0.094618
# Nov-2021                                          -0.019166
# Dez-2021                                           0.122379
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWEGE3  \
# Data
# Jan-2012                                           0.118807
# Fev-2012                                           0.005008
# Mar-2012                                          -0.023780
# Abr-2012                                          -0.020304
# Mai-2012                                          -0.033875
# ...                                                     ...
# Ago-2021                                          -0.003990
# Set-2021                                           0.054316
# Out-2021                                          -0.100050
# Nov-2021                                          -0.125338
# Dez-2021                                           0.031442
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nMNA  \
# Data
# Jan-2012                                           0.029699
# Fev-2012                                           0.011573
# Mar-2012                                           0.002621
# Abr-2012                                           0.009349
# Mai-2012                                          -0.035508
# ...                                                     ...
# Ago-2021                                          -0.011733
# Set-2021                                           0.000913
# Out-2021                                          -0.000608
# Nov-2021                                          -0.016433
# Dez-2021                                          -0.002166
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nNLR  \
# Data
# Jan-2012                                           0.121294
# Fev-2012                                           0.027043
# Mar-2012                                          -0.037455
# Abr-2012                                          -0.040116
# Mai-2012                                          -0.135529
# ...                                                     ...
# Ago-2021                                           0.037203
# Set-2021                                          -0.015281
# Out-2021                                           0.046458
# Nov-2021                                          -0.029472
# Dez-2021                                           0.038250
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVCIT  \
# Data
# Jan-2012                                           0.025896
# Fev-2012                                           0.006630
# Mar-2012                                          -0.007223
# Abr-2012                                           0.014675
# Mai-2012                                           0.004044
# ...                                                     ...
# Ago-2021                                          -0.003452
# Set-2021                                          -0.010430
# Out-2021                                          -0.003686
# Nov-2021                                          -0.003380
# Dez-2021                                           0.003170
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWTMF  \
# Data
# Jan-2012                                          -0.019014
# Fev-2012                                          -0.018481
# Mar-2012                                          -0.006659
# Abr-2012                                          -0.012252
# Mai-2012                                          -0.025743
# ...                                                     ...
# Ago-2021                                           0.008693
# Set-2021                                          -0.014900
# Out-2021                                           0.014123
# Nov-2021                                          -0.036108
# Dez-2021                                           0.013440
#
#           Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nHGLG11  \
# Data
# Jan-2012                                           0.094605
# Fev-2012                                           0.058813
# Mar-2012                                          -0.040468
# Abr-2012                                          -0.003907
# Mai-2012                                          -0.072917
# ...                                                     ...
# Ago-2021                                          -0.034234
# Set-2021                                          -0.035199
# Out-2021                                          -0.017849
# Nov-2021                                          -0.031599
# Dez-2021                                           0.080958
#
#           Carteira de Mercado Selecionada:S&P 500
# Data
# Jan-2012                                 0.043583
# Fev-2012                                 0.040589
# Mar-2012                                 0.031332
# Abr-2012                                -0.007497
# Mai-2012                                -0.062651
# ...                                           ...
# Ago-2021                                 0.028990
# Set-2021                                -0.047569
# Out-2021                                 0.069144
# Nov-2021                                -0.008334
# Dez-2021                                 0.043613
#
# [120 rows x 15 columns]

# %% [markdown]
# # Calculando o retorno esperado da carteira

# %%
retorno_mensal_esperado=carteira.mean()
retorno_mensal_esperado
# Out:
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBRK.B     0.012385
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBLK       0.017762
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nGME       0.148831
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nJPM       0.017810
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nORCL      0.012896
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nPETR4     0.011283
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nTSLA      0.058366
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVALE3     0.009765
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWEGE3     0.017805
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nMNA       0.002755
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nNLR       0.004967
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVCIT      0.003902
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWTMF     -0.000281
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nHGLG11    0.005581
# Carteira de Mercado Selecionada:S&P 500                                   0.011873
# dtype: float64

# %% [markdown]
# # Calculando a Matriz de Covariância

# %%
cov_carteira=carteira.cov()
cov_carteira
# Out:
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBRK.B  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001914
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001748
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.002257
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001930
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001237
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002423
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002097
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001904
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000944
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000140
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000779
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000077
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000124
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000920
# Carteira de Mercado Selecionada:S&P 500                                                      0.001223
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBLK  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001748
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004027
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.002801
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002765
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001949
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003440
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003056
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002231
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001393
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000192
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001172
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000133
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000118
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001428
# Carteira de Mercado Selecionada:S&P 500                                                      0.001901
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nGME  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.002257
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.002801
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           2.235605
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001926
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.008923
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.009580
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.017775
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.004148
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004552
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000515
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000956
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.001770
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002497
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.006580
# Carteira de Mercado Selecionada:S&P 500                                                     -0.001249
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nJPM  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001930
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002765
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001926
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004733
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001849
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004344
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002711
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003120
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001733
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000357
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001195
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000010
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000043
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001670
# Carteira de Mercado Selecionada:S&P 500                                                      0.001786
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nORCL  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001237
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001949
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.008923
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001849
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002923
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002575
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001718
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002081
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000708
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000203
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000967
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000134
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000033
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001024
# Carteira de Mercado Selecionada:S&P 500                                                      0.001309
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nPETR4  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002423
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003440
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.009580
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004344
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002575
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.030583
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.007261
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.016449
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.008368
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000578
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002593
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000888
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000128
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.010360
# Carteira de Mercado Selecionada:S&P 500                                                      0.002812
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nTSLA  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002097
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003056
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.017775
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002711
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001718
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.007261
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.033089
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002491
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003821
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000659
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001962
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000271
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000210
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002201
# Carteira de Mercado Selecionada:S&P 500                                                      0.002526
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVALE3  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001904
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002231
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.004148
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003120
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002081
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.016449
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002491
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.018152
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004501
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000214
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001763
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000337
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000062
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.006545
# Carteira de Mercado Selecionada:S&P 500                                                      0.001797
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWEGE3  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000944
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001393
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004552
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001733
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000708
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.008368
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.003821
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004501
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.009231
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000489
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001149
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000593
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000161
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004407
# Carteira de Mercado Selecionada:S&P 500                                                      0.001213
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nMNA  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000140
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000192
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000515
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000357
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000203
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000578
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000659
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000214
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000489
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000215
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000262
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000074
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000016
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000268
# Carteira de Mercado Selecionada:S&P 500                                                      0.000224
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nNLR  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000779
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001172
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000956
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001195
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000967
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002593
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001962
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001763
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001149
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000262
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001532
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000229
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000012
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001072
# Carteira de Mercado Selecionada:S&P 500                                                      0.000925
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVCIT  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000077
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000133
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.001770
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000010
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000134
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000888
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000271
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000337
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000593
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000074
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000229
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000209
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000013
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000440
# Carteira de Mercado Selecionada:S&P 500                                                      0.000194
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWTMF  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000124
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000118
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002497
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000043
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000033
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000128
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000210
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000062
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000161
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000016
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000012
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000013
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000305
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000027
# Carteira de Mercado Selecionada:S&P 500                                                      0.000046
#
#                                                     Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nHGLG11  \
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000920
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001428
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.006580
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001670
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001024
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.010360
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.002201
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.006545
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.004407
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000268
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.001072
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.000440
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                          -0.000027
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                           0.006306
# Carteira de Mercado Selecionada:S&P 500                                                      0.001229
#
#                                                     Carteira de Mercado Selecionada:S&P 500
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001223
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001901
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                -0.001249
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001786
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001309
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.002812
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.002526
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001797
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001213
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.000224
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.000925
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.000194
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.000046
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...                                 0.001229
# Carteira de Mercado Selecionada:S&P 500                                            0.001424

# %% [markdown]
# # Criando listas para salvar os pesos, o retorno , o desvio padão e o índice de sharpe da simulação das carteiras e simulando carteiras

# %%
peso_acoes=[]
retorno_cart=[]
desvio_cart=[]
sharpe_index=[]
for carteiras in range(num_sim):
    #criando um vetor randõmicos de números, com 15 posições
    a=-1
    b=1
    peso=(b-a)*np.random.random(num_acoes)+a
    #determinando o peso representativo de cada ativo, para isso dividimos cada peso pela soma do vetor pela soma de todos
    peso=peso/np.sum(peso)
    #calculando o retorno da carteira multiplicando o peso dos ativos pelo retorno de cada um
    retorno=np.dot(peso,retorno_mensal_esperado)
    #desvio padrão da carteira: multiplicando a matriz de pesos pela matriz de covariância e em sequência multiplica-se o resultado pela matiz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T,np.matmul(peso,np.array(cov_carteira))))
    #calculando o índice de sharpe para a carteira, já considerando o ativo livre de risco rf
    sharpe=(retorno-rf)/desvio
    #salvando as informações nas listas criadas anteriormente
    peso_acoes.append(peso)
    retorno_cart.append(retorno)
    desvio_cart.append(desvio)
    sharpe_index.append(sharpe)

# %% [markdown]
# # Criando um data frame com as informações de cada carteira aleatória gerada anteriormente;peso, retorno, desvio e o sharpe

# %%
dicionario={'Retorno':retorno_cart,'Desvio Padrão': desvio_cart,'Sharpe': sharpe_index}

# %%
for counter,ticker in enumerate(tickers):
    dicionario[ticker + ' peso'] = [peso[counter] for peso in peso_acoes]
    carteira2 = pd.DataFrame(dicionario)

carteira2
# Out:
#         Retorno  Desvio Padrão    Sharpe  \
# 0      0.094053       0.564587  0.163452
# 1     -0.011544       0.288643 -0.046127
# 2      0.067787       0.423924  0.155728
# 3      0.033041       0.413609  0.075605
# 4     -0.174819       2.495142 -0.070773
# ...         ...            ...       ...
# 99995 -0.013606       0.119764 -0.128382
# 99996  0.094694       0.729743  0.127339
# 99997  0.036654       0.151199  0.230719
# 99998 -0.058968       0.699539 -0.086826
# 99999  0.009239       0.077643  0.096203
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBRK.B peso  \
# 0                                               0.530214
# 1                                               0.410930
# 2                                              -0.175689
# 3                                              -0.370436
# 4                                               0.628404
# ...                                                  ...
# 99995                                           0.618571
# 99996                                           0.625866
# 99997                                          -0.824539
# 99998                                           0.001484
# 99999                                           0.125256
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nBLK peso  \
# 0                                               0.057822
# 1                                              -0.906073
# 2                                               0.207405
# 3                                               0.469149
# 4                                               0.400057
# ...                                                  ...
# 99995                                           0.239496
# 99996                                          -0.367159
# 99997                                           0.612995
# 99998                                          -0.497585
# 99999                                          -0.090524
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nGME peso  \
# 0                                               0.363552
# 1                                              -0.177771
# 2                                               0.277002
# 3                                               0.275099
# 4                                              -1.662560
# ...                                                  ...
# 99995                                          -0.017126
# 99996                                           0.480954
# 99997                                          -0.053760
# 99998                                          -0.467134
# 99999                                          -0.045328
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nJPM peso  \
# 0                                               0.474277
# 1                                              -0.243803
# 2                                               0.343911
# 3                                              -0.376148
# 4                                               0.842657
# ...                                                  ...
# 99995                                           0.603979
# 99996                                          -1.062946
# 99997                                           0.662285
# 99998                                           0.260209
# 99999                                           0.137358
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nORCL peso  \
# 0                                              -0.540976
# 1                                               0.063373
# 2                                               0.330271
# 3                                               0.272819
# 4                                               1.337227
# ...                                                  ...
# 99995                                          -0.450900
# 99996                                           0.782788
# 99997                                          -0.315276
# 99998                                           0.186628
# 99999                                           0.141104
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nPETR4 peso  \
# 0                                              -0.319300
# 1                                              -0.456317
# 2                                               0.189582
# 3                                               0.030356
# 4                                              -1.601635
# ...                                                  ...
# 99995                                           0.550870
# 99996                                          -0.131995
# 99997                                          -0.815084
# 99998                                          -0.081723
# 99999                                          -0.216712
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nTSLA peso  \
# 0                                               0.515963
# 1                                               0.242535
# 2                                               0.247171
# 3                                              -0.332430
# 4                                               0.287125
# ...                                                  ...
# 99995                                          -0.475365
# 99996                                           0.436877
# 99997                                           0.495726
# 99998                                           0.150040
# 99999                                           0.164943
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVALE3 peso  \
# 0                                               0.506576
# 1                                               0.855334
# 2                                              -0.238549
# 3                                              -0.170667
# 4                                               0.378917
# ...                                                  ...
# 99995                                          -0.399149
# 99996                                           0.731559
# 99997                                           0.567368
# 99998                                          -0.008086
# 99999                                           0.165961
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWEGE3 peso  \
# 0                                              -0.266950
# 1                                               0.828986
# 2                                               0.253501
# 3                                               0.480415
# 4                                               0.423497
# ...                                                  ...
# 99995                                          -0.536037
# 99996                                          -0.230715
# 99997                                           0.141773
# 99998                                          -0.286837
# 99999                                           0.068157
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nMNA peso  \
# 0                                              -0.498136
# 1                                              -0.053377
# 2                                              -0.124015
# 3                                              -0.386230
# 4                                               0.234133
# ...                                                  ...
# 99995                                           0.131238
# 99996                                          -0.981746
# 99997                                          -0.317932
# 99998                                           0.583909
# 99999                                           0.145740
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nNLR peso  \
# 0                                              -0.218832
# 1                                               0.216347
# 2                                              -0.150157
# 3                                               0.394738
# 4                                              -0.766220
# ...                                                  ...
# 99995                                           0.152065
# 99996                                          -0.247588
# 99997                                           0.066289
# 99998                                          -0.704400
# 99999                                           0.061144
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nVCIT peso  \
# 0                                               0.047382
# 1                                               0.389819
# 2                                              -0.212312
# 3                                               0.162447
# 4                                              -0.530982
# ...                                                  ...
# 99995                                           0.657208
# 99996                                           0.268720
# 99997                                           0.233409
# 99998                                           0.642716
# 99999                                           0.123047
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nWTMF peso  \
# 0                                              -0.234390
# 1                                               0.252036
# 2                                               0.136641
# 3                                               0.154183
# 4                                              -0.769753
# ...                                                  ...
# 99995                                          -0.337109
# 99996                                          -0.438677
# 99997                                          -0.124243
# 99998                                           0.356981
# 99999                                           0.168209
#
#        Retorno\ndo fechamento\nem 1 mês\nEm US Dollars\najust p/ prov\nHGLG11 peso  \
# 0                                               0.085202
# 1                                               0.007011
# 2                                               0.178148
# 3                                               0.395917
# 4                                               0.125925
# ...                                                  ...
# 99995                                          -0.026687
# 99996                                           1.116923
# 99997                                          -0.013219
# 99998                                           0.172898
# 99999                                          -0.001422
#
#        Carteira de Mercado Selecionada:S&P 500 peso
# 0                                          0.497595
# 1                                         -0.429032
# 2                                         -0.262911
# 3                                          0.000788
# 4                                          1.673208
# ...                                             ...
# 99995                                      0.288946
# 99996                                      0.017138
# 99997                                      0.684206
# 99998                                      0.690900
# 99999                                      0.053067
#
# [100000 rows x 18 columns]

# %% [markdown]
# # Plotando o sharpe de todas as carteiras simuladas em gráfico de retorno por desvio padrão

# %%
carteira2.plot.scatter(x='Desvio Padrão', y='Retorno', c='Sharpe', figsize=(16,8), grid = True, cmap='RdYlGn', edgecolors= 'black', xlim=(0,0.2), ylim=(-0.05,0.05))

# %% [markdown]
# # Localizando a carteira com maior sharpe

# %%
maior_sharpe= carteira2['Sharpe'].max()
carteira_maior_sharpe=carteira2.loc[carteira2['Sharpe']==maior_sharpe]
#aqui pegamos a matriz transposta para ter uma melhor vizualização dos dados
print(f'carteira com maior sharpe: {carteira_maior_sharpe.T}')
# Out:
# carteira com maior sharpe:                                                        55880
# Retorno                                             0.076115
# Desvio Padrão                                       0.178578
# Sharpe                                              0.416318
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.486095
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.791102
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.042927
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.697912
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.738235
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.350597
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.521670
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.293912
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.822728
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.286052
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.744143
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.089959
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.665309
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.749769
# Carteira de Mercado Selecionada:S&P 500 peso       -0.688669

# %% [markdown]
# # Criando a função de otimização, de soma dos pesos e encontrando a carteira otima a partir da biblioteca optimize

# %%
def otimizacao(peso, retorno_mesnsal_esperado, cov_carteira, rf):
    #primeiro calculamos o retorno da carteira multiplicando a matriz do peso pela matriz dos retornos esperados
    retorno= np.dot(peso, retorno_mensal_esperado)
    #segundo passo é calcular o desvio padrão da carteira, para isso multiplicamos a matriz de pesos pela matriz de covariãncias e multiplicamos esse resultado pela matriz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T, np.matmul(peso,np.array(cov_carteira))))
    #por fim calculamos o sharpe já considerando o ativo livre de riscos rf
    sharpe=-(retorno-rf)/desvio
    
    return sharpe

def soma_pesos(peso):
    soma=1
    soma=soma - np.sum(peso)
    return soma

restricao= {'type': 'eq', 'fun': soma_pesos}
start= np.random.random(num_acoes)
args= (retorno_mensal_esperado, cov_carteira, rf)
result= op.minimize(otimizacao, start, args=args, constraints=restricao)
pesos= result.x
carteiraOtima= pd.DataFrame({'Ativos': tickers, 'Pesos': pesos})
carteiraOtima.set_index(['Ativos'],inplace=True)
carteiraOtima
# Out:
#                                                        Pesos
# Ativos
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.444239
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.326951
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.012601
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.455998
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.287645
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.181719
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.264426
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.105715
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  0.171265
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -1.162945
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.920317
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars...  2.988715
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -1.383955
# Retorno\ndo fechamento\nem 1 mês\nEm US Dollars... -0.173971
# Carteira de Mercado Selecionada:S&P 500            -0.234648

# %%
#calculando o retorno da carteira multiplicando a matriz peso pela matriz dos retornos esperados
retorno_p= np.dot(pesos, retorno_mensal_esperado)
#calculando o desvio padrão da carteira multiplicando a matriz de pesos pela matriz de covariância e multiplicando esse resultado pela matriz transposta do peso
desvio_p= np.sqrt(np.matmul(pesos.T, np.matmul(pesos, np.array(cov_carteira))))
#calculando o índice de sharpe
sharpe_p= (retorno_p-rf)/desvio_p
pd.DataFrame([retorno_p, desvio_p, sharpe_p], ['E[r]', 'Risco','Sharpe'], ['carteira de ativos de risco otima'])
# Out:
#         carteira de ativos de risco otima
# E[r]                             0.043000
# Risco                            0.084506
# Sharpe                           0.487897

# %% [markdown]
# # Construindo a LAC

# %%
fim= max(carteira2['Desvio Padrão'])
x= np.linspace(0,fim,num_sim)
lac= sharpe_p*x + rf
plt.figure(num="Grafico de retorno por desvio padrão", figsize = (16,8), dpi=80)
plt.scatter(x=carteira2['Desvio Padrão'], y=carteira2['Retorno'], c=carteira2['Sharpe'], s=20, cmap='RdYlGn', edgecolors='black' )
#plt.scatter(x=carteira_sharpe['Desvio Padrão'], y=carteira_sharpe['Retorno'], s=50, edgecolors='black', label='Carteira Otima Otimização')      
plt.scatter(x=desvio_p, y=retorno_p, s=50,edgecolors='black', label='Carteira Otima Otimização')
plt.plot(x,lac,label='LAC')
plt.ylim((-0.12,0.1))
plt.xlim((0,0.2))
#plt.yticks(carteira_sharpe['Retorno'])
#plt.xticks(carteira_sharpe['Desvio Padrão'])
#plt.grid()
plt.legend()

# %% [markdown]
# # Criando a função utilidade e plotando o gráfico de cada perfil de investidor junto com a LAC

# %%
def retorno_utilidade_investidor(A, U):
    sigma= np.linspace(0,max(carteira2['Desvio Padrão']), num_sim)
    retorno= 0.5*A*sigma**2 + U
    return retorno

# %%
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
U=0.05
plt.plot(x, retorno_utilidade_investidor(20,U), label='Utilidade Conservador')
plt.plot(x, retorno_utilidade_investidor(10,U), label='Utilidade Moderado')
plt.plot(x, retorno_utilidade_investidor(5,U), label='Utilidade Agressivo')
plt.plot(x,lac,label='LAC')
plt.legend()

# %%
def CPO(A):
    y= (retorno_p-rf)/(A*desvio_p**2)
    retorno_c=y*retorno_p + (1-y)*rf
    desvio_c = ((y**2)*desvio_p**2)**(1/2)
    return retorno_c, desvio_c

def utilidade_investidor(A, retorno_c, desvio_c):
    utilidade_c= retorno_c - 0.5*A*desvio_c**2
    return utilidade_c

# %%
A=20
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Conservador')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.1))
plt.xlim((0,0.2))
plt.legend()

# %%
A=10
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Moderado')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.3))
plt.xlim((0,0.3))
plt.legend()

# %%
A=5
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Agressivo')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.1))
plt.xlim((0,0.2))
plt.legend()

# %% [markdown]
# # Portfólio 3

# %%
#taxa livre de risco
rf=0.1147
#numero de simulações da carteira
num_sim=100000
#base de dados com os retornos de cada ação
carteira=pd.read_excel(r'D:\Insper\Pasta3.xlsx')
#data como índice da tabela
carteira.set_index(['Data'],inplace=True)
#salvando os tickers em uma lista
tickers=list(carteira.columns)
#savando a contagem do número de ações em uma variável
num_acoes=len(tickers)
#tabela que contém a primeira coleção de ativos
carteira
# Out:
#               MSFT     ABEV3     B3SA3     BRK.B     ITSA4     PETR4  \
# Data
# Abr-2012 -0.007441  0.071143 -0.046263 -0.008626 -0.113739 -0.088223
# Mai-2012 -0.082257 -0.071503 -0.098467 -0.013549 -0.027594 -0.092159
# Jun-2012  0.047962  0.015305  0.073298  0.050025 -0.033542 -0.046001
# Jul-2012 -0.036613  0.018049  0.121951  0.018121  0.130588  0.068493
# Ago-2012  0.052737 -0.008243 -0.055303 -0.005893 -0.027055  0.064103
# ...            ...       ...       ...       ...       ...       ...
# Ago-2021  0.061591  0.027644 -0.077377  0.026878  0.038283  0.070585
# Set-2021 -0.066119 -0.105263 -0.080702 -0.044896 -0.034662  0.001471
# Out-2021  0.176291  0.110458 -0.065149  0.051550 -0.079892  0.000734
# Nov-2021 -0.001282 -0.054738 -0.067170 -0.035957 -0.041669  0.080000
# Dez-2021  0.017333 -0.002379  0.015475  0.080632 -0.025588  0.085953
#
#                 TM       DIS    USDJPY    BOVA11       IVV    SMAL11  \
# Data
# Abr-2012 -0.058051 -0.015304 -0.035357 -0.041549 -0.006586 -0.003099
# Mai-2012 -0.059795  0.060311 -0.019765 -0.119869 -0.060094 -0.152303
# Jun-2012  0.046690  0.061037  0.018504 -0.003358  0.042080  0.057167
# Jul-2012 -0.049329  0.013196 -0.021050  0.031449  0.012431  0.020968
# Ago-2012  0.040648  0.006716  0.003328  0.019056  0.024774  0.078289
# ...            ...       ...       ...       ...       ...       ...
# Ago-2021 -0.031194  0.029997  0.001641 -0.025873  0.030223 -0.038575
# Set-2021  0.031915 -0.066906  0.016386 -0.066532 -0.046837 -0.065503
# Out-2021 -0.006639 -0.000591  0.017107 -0.063950  0.070029 -0.127159
# Nov-2021  0.007249 -0.142959  0.000264 -0.013343 -0.007289 -0.021583
# Dez-2021  0.041889  0.068944  0.013241  0.024911  0.045619  0.041360
#
#           TESOURO IPCA BTG    HGLG11    HGBS11  RENDA FIXA PRE FIXADA BB  \
# Data
# Abr-2012          0.041829  0.030588  0.022525                  0.016715
# Mai-2012          0.022064 -0.005495  0.014933                  0.013955
# Jun-2012         -0.004992  0.034208  0.074567                  0.012119
# Jul-2012          0.028573  0.025542  0.106247                  0.010268
# Ago-2012          0.016031 -0.013667  0.007918                  0.005981
# ...                    ...       ...       ...                       ...
# Ago-2021         -0.011043 -0.030142 -0.050718                 -0.006815
# Set-2021         -0.001658  0.020345 -0.029060                 -0.004204
# Out-2021         -0.025613  0.018914 -0.006842                 -0.027307
# Nov-2021          0.034466 -0.035564 -0.112842                  0.017663
# Dez-2021          0.002006  0.073379  0.215851                  0.018342
#
#           ETF INDEX EUROPEU      OURO  Retorno IBOVESPA
# Data
# Abr-2012          -0.023103  0.053292         -0.041699
# Mai-2012          -0.106296  0.001984         -0.118570
# Jun-2012           0.080666  0.023267         -0.002496
# Jul-2012           0.009122  0.025641          0.032068
# Ago-2012           0.036157  0.046698          0.017185
# ...                     ...       ...               ...
# Ago-2021           0.015032 -0.018092         -0.024793
# Set-2021          -0.054016  0.018425         -0.065683
# Out-2021           0.052608  0.047697         -0.067386
# Nov-2021          -0.047020  0.004710         -0.015316
# Dez-2021           0.047592  0.031250          0.028524
#
# [117 rows x 19 columns]

# %% [markdown]
# # Calculando o retorno esperado da carteira

# %%
retorno_mensal_esperado=carteira.mean()
retorno_mensal_esperado
# Out:
# MSFT                        0.023691
# ABEV3                       0.006597
# B3SA3                       0.016613
# BRK.B                       0.012168
# ITSA4                       0.011489
# PETR4                       0.015036
# TM                          0.010017
# DIS                         0.014068
# USDJPY                      0.003086
# BOVA11                      0.006185
# IVV                         0.012844
# SMAL11                      0.006667
# TESOURO IPCA BTG            0.008718
# HGLG11                      0.012515
# HGBS11                      0.007879
# RENDA FIXA PRE FIXADA BB    0.007043
# ETF INDEX EUROPEU           0.006377
# OURO                        0.011996
# Retorno IBOVESPA            0.006351
# dtype: float64

# %% [markdown]
# # Calculando a Matriz de Covariância

# %%
cov_carteira=carteira.cov()
cov_carteira
# Out:
#                               MSFT     ABEV3     B3SA3     BRK.B     ITSA4  \
# MSFT                      0.003451  0.000415  0.000719  0.000933  0.000548
# ABEV3                     0.000415  0.004298  0.002264  0.000861  0.002337
# B3SA3                     0.000719  0.002264  0.007910  0.000886  0.004851
# BRK.B                     0.000933  0.000861  0.000886  0.001956  0.001282
# ITSA4                     0.000548  0.002337  0.004851  0.001282  0.006356
# PETR4                     0.002713  0.002239  0.008713  0.001930  0.007933
# TM                        0.000924  0.001076  0.000442  0.000705  0.000872
# DIS                       0.001380  0.001316  0.001491  0.001754  0.001366
# USDJPY                    0.000299  0.000078 -0.000422  0.000228 -0.000215
# BOVA11                    0.001045  0.002021  0.004541  0.001180  0.004418
# IVV                       0.001338  0.000957  0.001007  0.001253  0.001016
# SMAL11                    0.001048  0.002032  0.004345  0.001260  0.003966
# TESOURO IPCA BTG         -0.000107  0.000430  0.001085  0.000143  0.001039
# HGLG11                    0.000678  0.000938  0.001669  0.000394  0.001549
# HGBS11                    0.000199  0.000827  0.001724  0.000496  0.001700
# RENDA FIXA PRE FIXADA BB -0.000120  0.000113  0.000457  0.000014  0.000392
# ETF INDEX EUROPEU         0.001206  0.001513  0.001519  0.001211  0.001453
# OURO                     -0.000553 -0.000661 -0.000847 -0.000606 -0.001351
# Retorno IBOVESPA          0.001003  0.002009  0.004533  0.001176  0.004407
#
#                              PETR4            TM       DIS    USDJPY  \
# MSFT                      0.002713  9.237421e-04  0.001380  0.000299
# ABEV3                     0.002239  1.075577e-03  0.001316  0.000078
# B3SA3                     0.008713  4.418161e-04  0.001491 -0.000422
# BRK.B                     0.001930  7.045353e-04  0.001754  0.000228
# ITSA4                     0.007933  8.717598e-04  0.001366 -0.000215
# PETR4                     0.020514  1.486916e-03  0.002706 -0.000457
# TM                        0.001487  2.296113e-03  0.001322  0.000401
# DIS                       0.002706  1.322076e-03  0.004662  0.000226
# USDJPY                   -0.000457  4.014563e-04  0.000226  0.000557
# BOVA11                    0.008021  8.254342e-04  0.001648 -0.000200
# IVV                       0.002326  8.058623e-04  0.001715  0.000159
# SMAL11                    0.007174  9.483542e-04  0.001806 -0.000198
# TESOURO IPCA BTG          0.001590  8.846386e-05  0.000273 -0.000124
# HGLG11                    0.003443  4.455639e-04  0.000936 -0.000081
# HGBS11                    0.002992  4.691244e-04  0.000756 -0.000067
# RENDA FIXA PRE FIXADA BB  0.000609  4.029884e-07  0.000069 -0.000066
# ETF INDEX EUROPEU         0.003017  9.504509e-04  0.001862  0.000131
# OURO                     -0.002732 -6.683650e-04 -0.001064 -0.000366
# Retorno IBOVESPA          0.007969  8.363721e-04  0.001649 -0.000208
#
#                             BOVA11       IVV    SMAL11  TESOURO IPCA BTG  \
# MSFT                      0.001045  0.001338  0.001048         -0.000107
# ABEV3                     0.002021  0.000957  0.002032          0.000430
# B3SA3                     0.004541  0.001007  0.004345          0.001085
# BRK.B                     0.001180  0.001253  0.001260          0.000143
# ITSA4                     0.004418  0.001016  0.003966          0.001039
# PETR4                     0.008021  0.002326  0.007174          0.001590
# TM                        0.000825  0.000806  0.000948          0.000088
# DIS                       0.001648  0.001715  0.001806          0.000273
# USDJPY                   -0.000200  0.000159 -0.000198         -0.000124
# BOVA11                    0.004329  0.001287  0.004213          0.000881
# IVV                       0.001287  0.001439  0.001418          0.000157
# SMAL11                    0.004213  0.001418  0.004988          0.000897
# TESOURO IPCA BTG          0.000881  0.000157  0.000897          0.000501
# HGLG11                    0.001583  0.000689  0.001744          0.000390
# HGBS11                    0.001551  0.000460  0.001671          0.000487
# RENDA FIXA PRE FIXADA BB  0.000317  0.000001  0.000325          0.000193
# ETF INDEX EUROPEU         0.001721  0.001398  0.001903          0.000303
# OURO                     -0.001007 -0.000438 -0.000979         -0.000270
# Retorno IBOVESPA          0.004294  0.001260  0.004178          0.000879
#
#                             HGLG11    HGBS11  RENDA FIXA PRE FIXADA BB  \
# MSFT                      0.000678  0.000199             -1.200205e-04
# ABEV3                     0.000938  0.000827              1.126354e-04
# B3SA3                     0.001669  0.001724              4.571890e-04
# BRK.B                     0.000394  0.000496              1.394609e-05
# ITSA4                     0.001549  0.001700              3.923499e-04
# PETR4                     0.003443  0.002992              6.091215e-04
# TM                        0.000446  0.000469              4.029884e-07
# DIS                       0.000936  0.000756              6.868422e-05
# USDJPY                   -0.000081 -0.000067             -6.565825e-05
# BOVA11                    0.001583  0.001551              3.166467e-04
# IVV                       0.000689  0.000460              1.093667e-06
# SMAL11                    0.001744  0.001671              3.253553e-04
# TESOURO IPCA BTG          0.000390  0.000487              1.927882e-04
# HGLG11                    0.002561  0.001581              1.632179e-04
# HGBS11                    0.001581  0.003027              2.292379e-04
# RENDA FIXA PRE FIXADA BB  0.000163  0.000229              1.130091e-04
# ETF INDEX EUROPEU         0.000809  0.000861              7.557013e-05
# OURO                     -0.000462 -0.000368             -1.141035e-04
# Retorno IBOVESPA          0.001556  0.001548              3.203792e-04
#
#                           ETF INDEX EUROPEU      OURO  Retorno IBOVESPA
# MSFT                               0.001206 -0.000553          0.001003
# ABEV3                              0.001513 -0.000661          0.002009
# B3SA3                              0.001519 -0.000847          0.004533
# BRK.B                              0.001211 -0.000606          0.001176
# ITSA4                              0.001453 -0.001351          0.004407
# PETR4                              0.003017 -0.002732          0.007969
# TM                                 0.000950 -0.000668          0.000836
# DIS                                0.001862 -0.001064          0.001649
# USDJPY                             0.000131 -0.000366         -0.000208
# BOVA11                             0.001721 -0.001007          0.004294
# IVV                                0.001398 -0.000438          0.001260
# SMAL11                             0.001903 -0.000979          0.004178
# TESOURO IPCA BTG                   0.000303 -0.000270          0.000879
# HGLG11                             0.000809 -0.000462          0.001556
# HGBS11                             0.000861 -0.000368          0.001548
# RENDA FIXA PRE FIXADA BB           0.000076 -0.000114          0.000320
# ETF INDEX EUROPEU                  0.001989 -0.000691          0.001706
# OURO                              -0.000691  0.002769         -0.001039
# Retorno IBOVESPA                   0.001706 -0.001039          0.004270

# %% [markdown]
# # Criando listas para salvar os pesos, o retorno , o desvio padão e o índice de sharpe da simulação das carteiras e simulando carteiras

# %%
peso_acoes=[]
retorno_cart=[]
desvio_cart=[]
sharpe_index=[]
for carteiras in range(num_sim):
    #criando um vetor randõmicos de números, com 15 posições
    a=-1
    b=1
    peso=(b-a)*np.random.random(num_acoes)+a
    #determinando o peso representativo de cada ativo, para isso dividimos cada peso pela soma do vetor pela soma de todos
    peso=peso/np.sum(peso)
    #calculando o retorno da carteira multiplicando o peso dos ativos pelo retorno de cada um
    retorno=np.dot(peso,retorno_mensal_esperado)
    #desvio padrão da carteira: multiplicando a matriz de pesos pela matriz de covariância e em sequência multiplica-se o resultado pela matiz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T,np.matmul(peso,np.array(cov_carteira))))
    #calculando o índice de sharpe para a carteira, já considerando o ativo livre de risco rf
    sharpe=(retorno-rf)/desvio
    #salvando as informações nas listas criadas anteriormente
    peso_acoes.append(peso)
    retorno_cart.append(retorno)
    desvio_cart.append(desvio)
    sharpe_index.append(sharpe)

# %% [markdown]
# # Criando um data frame com as informações de cada carteira aleatória gerada anteriormente;peso, retorno, desvio e o sharpe

# %%
dicionario={'Retorno':retorno_cart,'Desvio Padrão': desvio_cart,'Sharpe': sharpe_index}

# %%
for counter,ticker in enumerate(tickers):
    dicionario[ticker + ' peso'] = [peso[counter] for peso in peso_acoes]
    carteira2 = pd.DataFrame(dicionario)

carteira2
# Out:
#         Retorno  Desvio Padrão    Sharpe   MSFT peso  ABEV3 peso  B3SA3 peso  \
# 0      0.019647       0.079318 -1.198390    0.350317    0.062473   -0.077408
# 1     -0.002365       0.201020 -0.582353    0.114573    0.924852   -1.018588
# 2     -3.531187      60.406879 -0.060356 -396.896686  -39.103448  373.584657
# 3      0.056951       0.302358 -0.190997    2.246442    1.649452    2.380019
# 4      0.007939       0.051296 -2.081288    0.267381    0.129469    0.239680
# ...         ...            ...       ...         ...         ...         ...
# 99995  0.003543       0.053879 -2.063076   -0.504845   -0.172805   -0.270014
# 99996  0.012418       0.067288 -1.520063    0.450012   -0.274640   -0.157513
# 99997  0.013192       0.052218 -1.943906    0.246708   -0.019483    0.184832
# 99998  0.017882       0.061432 -1.576015    0.429295   -0.230266    0.152954
# 99999  0.207483       1.691840  0.054841    9.951368   -3.791737   13.570769
#
#        BRK.B peso  ITSA4 peso  PETR4 peso     TM peso  ...  BOVA11 peso  \
# 0        0.346787    0.045675    0.201305    0.416878  ...    -0.446267
# 1        0.686085   -0.280568   -0.947959    0.421669  ...    -0.999597
# 2      281.687179 -272.977567 -275.773454  362.813416  ...    66.729812
# 3        0.925432   -1.302066   -2.430819   -0.532690  ...    -1.955028
# 4       -0.017189    0.221562   -0.348135   -0.144777  ...     0.059578
# ...           ...         ...         ...         ...  ...          ...
# 99995    0.224679    0.188860    0.473964    0.036349  ...    -0.206116
# 99996   -0.011730   -0.453749   -0.108747   -0.246701  ...     0.322210
# 99997   -0.011698   -0.272184    0.197700    0.114102  ...     0.193750
# 99998    0.063312   -0.022283   -0.402708    0.321092  ...     0.341929
# 99999    6.094974    9.304641  -12.480664   13.356156  ...    14.908498
#
#         IVV peso  SMAL11 peso  TESOURO IPCA BTG peso  HGLG11 peso  \
# 0       0.204588    -0.435150              -0.289357     0.343572
# 1       0.104374     0.885913               0.694709     0.584057
# 2     -11.908933  -418.720264             412.262125   129.536363
# 3       1.677078    -0.664519              -0.764707     2.020215
# 4       0.152226    -0.099301               0.061041     0.214552
# ...          ...          ...                    ...          ...
# 99995   0.183203    -0.396624               0.159055    -0.441617
# 99996   0.276129     0.293996              -0.013028     0.197678
# 99997  -0.307508     0.117475              -0.306028     0.037693
# 99998   0.178450     0.350235               0.123560     0.209242
# 99999 -10.511122   -10.708399              -2.786057     2.886045
#
#        HGBS11 peso  RENDA FIXA PRE FIXADA BB peso  ETF INDEX EUROPEU peso  \
# 0         0.387901                       0.173087                0.138954
# 1        -0.247497                       0.188426                0.243499
# 2       120.429251                    -264.929781               23.566258
# 3         1.987364                      -0.241935               -1.623110
# 4        -0.014484                       0.254570               -0.409049
# ...            ...                            ...                     ...
# 99995     0.069374                       0.500937                0.360549
# 99996     0.250991                      -0.289172                0.343967
# 99997    -0.194680                       0.290487                0.309385
# 99998    -0.340063                       0.011121                0.102020
# 99999    11.640672                      -8.678107               -4.075028
#
#         OURO peso  Retorno IBOVESPA peso
# 0        0.584614              -0.537706
# 1       -0.395067               0.001030
# 2      141.808925              11.865651
# 3       -0.905472               2.925326
# 4        0.066885               0.435896
# ...           ...                    ...
# 99995    0.296987              -0.161041
# 99996    0.038092              -0.301027
# 99997    0.227416              -0.021317
# 99998   -0.175315              -0.141319
# 99999   -3.480401               3.018277
#
# [100000 rows x 22 columns]

# %% [markdown]
# # Plotando o sharpe de todas as carteiras simuladas em gráfico de retorno por desvio padrão

# %%
carteira2.plot.scatter(x='Desvio Padrão', y='Retorno', c='Sharpe', figsize=(16,8), grid = True, cmap='RdYlGn', edgecolors= 'black', xlim=(0,0.2), ylim=(-0.05,0.05))

# %% [markdown]
# # Localizando a carteira com maior sharpe

# %%
maior_sharpe= carteira2['Sharpe'].max()
carteira_maior_sharpe=carteira2.loc[carteira2['Sharpe']==maior_sharpe]
#aqui pegamos a matriz transposta para ter uma melhor vizualização dos dados
print(f'carteira com maior sharpe: {carteira_maior_sharpe.T}')
# Out:
# carteira com maior sharpe:                                    87073
# Retorno                         2.639800
# Desvio Padrão                   8.591448
# Sharpe                          0.293908
# MSFT peso                      63.196489
# ABEV3 peso                    -63.775424
# B3SA3 peso                     32.126259
# BRK.B peso                     12.779541
# ITSA4 peso                     85.743363
# PETR4 peso                     -5.979923
# TM peso                        92.504597
# DIS peso                       70.470052
# USDJPY peso                   -95.028606
# BOVA11 peso                   -93.300852
# IVV peso                      -38.807099
# SMAL11 peso                   -26.587956
# TESOURO IPCA BTG peso         -37.725063
# HGLG11 peso                   -11.076762
# HGBS11 peso                     9.942769
# RENDA FIXA PRE FIXADA BB peso  44.993117
# ETF INDEX EUROPEU peso          3.604792
# OURO peso                     -13.540366
# Retorno IBOVESPA peso         -28.538927

# %% [markdown]
# # Criando a função de otimização, de soma dos pesos e encontrando a carteira otima a partir da biblioteca optimize

# %%
def otimizacao(peso, retorno_mesnsal_esperado, cov_carteira, rf):
    #primeiro calculamos o retorno da carteira multiplicando a matriz do peso pela matriz dos retornos esperados
    retorno= np.dot(peso, retorno_mensal_esperado)
    #segundo passo é calcular o desvio padrão da carteira, para isso multiplicamos a matriz de pesos pela matriz de covariãncias e multiplicamos esse resultado pela matriz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T, np.matmul(peso,np.array(cov_carteira))))
    #por fim calculamos o sharpe já considerando o ativo livre de riscos rf
    sharpe=-(retorno-rf)/desvio
    
    return sharpe

def soma_pesos(peso):
    soma=1
    soma=soma - np.sum(peso)
    return soma

restricao= {'type': 'eq', 'fun': soma_pesos}
start= np.random.random(num_acoes)
args= (retorno_mensal_esperado, cov_carteira, rf)
result= op.minimize(otimizacao, start, args=args, constraints=restricao)
pesos= result.x
carteiraOtima= pd.DataFrame({'Ativos': tickers, 'Pesos': pesos})
carteiraOtima.set_index(['Ativos'],inplace=True)
carteiraOtima
# Out:
#                                  Pesos
# Ativos
# MSFT                      20709.263677
# ABEV3                    -13133.636640
# B3SA3                     27967.354188
# BRK.B                     -8852.322489
# ITSA4                     17692.704089
# PETR4                     46192.188819
# TM                       -11057.263954
# DIS                        1233.267483
# USDJPY                   -21065.669500
# BOVA11                     2888.557919
# IVV                       -5389.530769
# SMAL11                     -644.169952
# TESOURO IPCA BTG          -6465.154799
# HGLG11                     4584.262553
# HGBS11                   -10424.779921
# RENDA FIXA PRE FIXADA BB -11740.928700
# ETF INDEX EUROPEU        -14876.063946
# OURO                     -20765.173137
# Retorno IBOVESPA           3148.095079

# %%
#calculando o retorno da carteira multiplicando a matriz peso pela matriz dos retornos esperados
retorno_p= np.dot(pesos, retorno_mensal_esperado)
#calculando o desvio padrão da carteira multiplicando a matriz de pesos pela matriz de covariância e multiplicando esse resultado pela matriz transposta do peso
desvio_p= np.sqrt(np.matmul(pesos.T, np.matmul(pesos, np.array(cov_carteira))))
#calculando o índice de sharpe
sharpe_p= (retorno_p-rf)/desvio_p
pd.DataFrame([retorno_p, desvio_p, sharpe_p], ['E[r]', 'Risco','Sharpe'], ['carteira de ativos de risco otima'])
# Out:
#         carteira de ativos de risco otima
# E[r]                           956.827133
# Risco                         9772.960935
# Sharpe                           0.097894

# %% [markdown]
# # Construindo a LAC

# %%
fim= max(carteira2['Desvio Padrão'])
x= np.linspace(0,fim,num_sim)
lac= sharpe_p*x + rf
plt.figure(num="Grafico de retorno por desvio padrão", figsize = (16,8), dpi=80)
plt.scatter(x=carteira2['Desvio Padrão'], y=carteira2['Retorno'], c=carteira2['Sharpe'], s=20, cmap='RdYlGn', edgecolors='black' )
#plt.scatter(x=carteira_sharpe['Desvio Padrão'], y=carteira_sharpe['Retorno'], s=50, edgecolors='black', label='Carteira Otima Otimização')      
plt.scatter(x=desvio_p, y=retorno_p, s=50,edgecolors='black', label='Carteira Otima Otimização')
plt.plot(x,lac,label='LAC')
plt.ylim((-0.12,1300))
plt.xlim((0,13000))
#plt.yticks(carteira_sharpe['Retorno'])
#plt.xticks(carteira_sharpe['Desvio Padrão'])
#plt.grid()
plt.legend()

# %% [markdown]
# # Criando a função utilidade e plotando o gráfico de cada perfil de investidor junto com a LAC

# %%
def retorno_utilidade_investidor(A, U):
    sigma= np.linspace(0,max(carteira2['Desvio Padrão']), num_sim)
    retorno= 0.5*A*sigma**2 + U
    return retorno

# %%
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
U=0.05
plt.plot(x, retorno_utilidade_investidor(20,U), label='Utilidade Conservador')
plt.plot(x, retorno_utilidade_investidor(10,U), label='Utilidade Moderado')
plt.plot(x, retorno_utilidade_investidor(5,U), label='Utilidade Agressivo')
plt.plot(x,lac,label='LAC')
plt.legend()

# %%
def CPO(A):
    y= (retorno_p-rf)/(A*desvio_p**2)
    retorno_c=y*retorno_p + (1-y)*rf
    desvio_c = ((y**2)*desvio_p**2)**(1/2)
    return retorno_c, desvio_c

def utilidade_investidor(A, retorno_c, desvio_c):
    utilidade_c= retorno_c - 0.5*A*desvio_c**2
    return utilidade_c

# %%
A=20
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Conservador')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((-0.5,1))
plt.xlim((-0.25,2))
plt.legend()

# %%
A=10
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Moderado')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.3))
plt.xlim((0,0.3))
plt.legend()

# %%
A=5
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Agressivo')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((-0.25,0.5))
plt.xlim((-0.25,1))
plt.legend()

# %% [markdown]
# # Portfólio 4

# %%
#taxa livre de risco
rf=0.0106
#numero de simulações da carteira
num_sim=100000
#base de dados com os retornos de cada ação
carteira=pd.read_excel(r'D:\Insper\Pasta4.xlsx')
#data como índice da tabela
carteira.set_index(['Data'],inplace=True)
#salvando os tickers em uma lista
tickers=list(carteira.columns)
#savando a contagem do número de ações em uma variável
num_acoes=len(tickers)
#tabela que contém a primeira coleção de ativos
carteira
# Out:
#              ABEV3     ITUB3     GGBR3     LREN3     VALE3      IBOV  \
# Data
# Jan-2012  0.117692  0.040094  0.063828  0.108136 -0.025727  0.043427
# Fev-2012  0.098186 -0.030977 -0.023288 -0.038583 -0.014925 -0.019769
# Mar-2012  0.071143 -0.108800  0.041374  0.000977  0.017999 -0.041699
# Abr-2012 -0.071503 -0.039110 -0.078135 -0.050922 -0.117606 -0.118570
# Mai-2012  0.015305 -0.019108  0.071900 -0.028253  0.067571 -0.002496
# ...            ...       ...       ...       ...       ...       ...
# Ago-2021 -0.105263 -0.056439 -0.031215 -0.092465 -0.147146 -0.065683
# Set-2021  0.110458 -0.041571  0.000900 -0.063626 -0.060729 -0.067386
# Out-2021 -0.054738 -0.030745  0.026579 -0.029010 -0.023181 -0.015316
# Nov-2021 -0.002379 -0.049414  0.067966 -0.136441  0.114510  0.028524
# Dez-2021 -0.029183  0.158221  0.005785  0.150573  0.037327  0.069843
#
#              BBDC3     FLRY3     VIIA3     RENT3     IGTA3     MGLU3  \
# Data
# Jan-2012  0.029460  0.071772  0.379310  0.105612  0.112604  0.182635
# Fev-2012  0.025695 -0.015925  0.000000  0.061595  0.014493  0.009283
# Mar-2012 -0.051421  0.019087 -0.166667 -0.031250  0.006750 -0.048495
# Abr-2012 -0.036454 -0.017101 -0.050000 -0.012859 -0.075454 -0.179069
# Mai-2012  0.010740  0.056338 -0.052632 -0.051562  0.071798  0.007503
# ...            ...       ...       ...       ...       ...       ...
# Ago-2021 -0.103538 -0.065089 -0.257940 -0.015888 -0.077508 -0.213816
# Set-2021 -0.047251 -0.148734 -0.202335 -0.168350 -0.050729 -0.246165
# Out-2021  0.002161 -0.072225 -0.078049  0.128256  0.106546 -0.278446
# Nov-2021 -0.035166  0.035223 -0.074074  0.039344  0.000000 -0.074359
# Dez-2021  0.162422  0.123958 -0.100952  0.105660  0.000000 -0.030471
#
#              EMBR3      OZ1D  DOLAR AMERICANO
# Data
# Jan-2012  0.061360  0.004184           -0.017
# Fev-2012  0.143750 -0.003125            0.063
# Mar-2012  0.122951  0.053292            0.045
# Abr-2012 -0.127129  0.001984            0.060
# Mai-2012 -0.062509  0.023267           -0.006
# ...            ...       ...              ...
# Ago-2021 -0.012383  0.018425            0.057
# Set-2021 -0.051881  0.047697            0.036
# Out-2021 -0.127223  0.004710           -0.002
# Nov-2021  0.296761  0.031250           -0.010
# Dez-2021 -0.181708 -0.083333           -0.048
#
# [120 rows x 15 columns]

# %% [markdown]
# # Calculando o retorno esperado da carteira

# %%
retorno_mensal_esperado=carteira.mean()
retorno_mensal_esperado
# Out:
# ABEV3              0.007988
# ITUB3              0.012670
# GGBR3              0.014528
# LREN3              0.015044
# VALE3              0.015269
# IBOV               0.006971
# BBDC3              0.012657
# FLRY3              0.011960
# VIIA3              0.025271
# RENT3              0.022978
# IGTA3              0.009554
# MGLU3              0.043908
# EMBR3              0.011186
# OZ1D               0.011010
# DOLAR AMERICANO    0.010300
# dtype: float64

# %% [markdown]
# # Calculando a Matriz de Covariância

# %%
cov_carteira=carteira.cov()
cov_carteira
# Out:
#                     ABEV3     ITUB3     GGBR3     LREN3     VALE3      IBOV  \
# ABEV3            0.004372  0.001923  0.002150  0.002081  0.001094  0.001953
# ITUB3            0.001923  0.005492  0.004367  0.004222  0.002563  0.003959
# GGBR3            0.002150  0.004367  0.016571  0.003617  0.008216  0.005435
# LREN3            0.002081  0.004222  0.003617  0.007475  0.001603  0.004113
# VALE3            0.001094  0.002563  0.008216  0.001603  0.011884  0.003844
# IBOV             0.001953  0.003959  0.005435  0.004113  0.003844  0.004214
# BBDC3            0.002835  0.005872  0.006160  0.005455  0.003399  0.005010
# FLRY3            0.001612  0.002006  0.005143  0.002974  0.002041  0.002812
# VIIA3            0.003324  0.004768  0.007615  0.007062  0.004376  0.006586
# RENT3            0.001649  0.003831  0.006567  0.005033  0.002368  0.004444
# IGTA3            0.002424  0.003881  0.004448  0.005428  0.002075  0.003951
# MGLU3            0.000483  0.004570  0.007332  0.004998  0.006668  0.005231
# EMBR3            0.001694  0.000919  0.000682  0.000663  0.001528  0.001212
# OZ1D            -0.000633 -0.001380 -0.000926 -0.001220 -0.000997 -0.001063
# DOLAR AMERICANO -0.000989 -0.002010 -0.001953 -0.002016 -0.001711 -0.001955
#
#                     BBDC3     FLRY3     VIIA3     RENT3     IGTA3     MGLU3  \
# ABEV3            0.002835  0.001612  0.003324  0.001649  0.002424  0.000483
# ITUB3            0.005872  0.002006  0.004768  0.003831  0.003881  0.004570
# GGBR3            0.006160  0.005143  0.007615  0.006567  0.004448  0.007332
# LREN3            0.005455  0.002974  0.007062  0.005033  0.005428  0.004998
# VALE3            0.003399  0.002041  0.004376  0.002368  0.002075  0.006668
# IBOV             0.005010  0.002812  0.006586  0.004444  0.003951  0.005231
# BBDC3            0.008547  0.002954  0.008138  0.005245  0.005555  0.004808
# FLRY3            0.002954  0.008374  0.007871  0.004283  0.002630  0.007428
# VIIA3            0.008138  0.007871  0.040962  0.009382  0.007311  0.013491
# RENT3            0.005245  0.004283  0.009382  0.009624  0.005329  0.007350
# IGTA3            0.005555  0.002630  0.007311  0.005329  0.006802  0.003952
# MGLU3            0.004808  0.007428  0.013491  0.007350  0.003952  0.039118
# EMBR3            0.001108  0.000613 -0.000127  0.000272  0.001557 -0.000447
# OZ1D            -0.001663 -0.000692 -0.000871 -0.001081 -0.000966 -0.000186
# DOLAR AMERICANO -0.002624 -0.001276 -0.003110 -0.002236 -0.002134 -0.002544
#
#                     EMBR3      OZ1D  DOLAR AMERICANO
# ABEV3            0.001694 -0.000633        -0.000989
# ITUB3            0.000919 -0.001380        -0.002010
# GGBR3            0.000682 -0.000926        -0.001953
# LREN3            0.000663 -0.001220        -0.002016
# VALE3            0.001528 -0.000997        -0.001711
# IBOV             0.001212 -0.001063        -0.001955
# BBDC3            0.001108 -0.001663        -0.002624
# FLRY3            0.000613 -0.000692        -0.001276
# VIIA3           -0.000127 -0.000871        -0.003110
# RENT3            0.000272 -0.001081        -0.002236
# IGTA3            0.001557 -0.000966        -0.002134
# MGLU3           -0.000447 -0.000186        -0.002544
# EMBR3            0.012244 -0.000963        -0.000552
# OZ1D            -0.000963  0.002777         0.001449
# DOLAR AMERICANO -0.000552  0.001449         0.002015

# %% [markdown]
# # Criando listas para salvar os pesos, o retorno , o desvio padão e o índice de sharpe da simulação das carteiras e simulando carteiras

# %%
peso_acoes=[]
retorno_cart=[]
desvio_cart=[]
sharpe_index=[]
for carteiras in range(num_sim):
    #criando um vetor randõmicos de números, com 15 posições
    a=-1
    b=1
    peso=(b-a)*np.random.random(num_acoes)+a
    #determinando o peso representativo de cada ativo, para isso dividimos cada peso pela soma do vetor pela soma de todos
    peso=peso/np.sum(peso)
    #calculando o retorno da carteira multiplicando o peso dos ativos pelo retorno de cada um
    retorno=np.dot(peso,retorno_mensal_esperado)
    #desvio padrão da carteira: multiplicando a matriz de pesos pela matriz de covariância e em sequência multiplica-se o resultado pela matiz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T,np.matmul(peso,np.array(cov_carteira))))
    #calculando o índice de sharpe para a carteira, já considerando o ativo livre de risco rf
    sharpe=(retorno-rf)/desvio
    #salvando as informações nas listas criadas anteriormente
    peso_acoes.append(peso)
    retorno_cart.append(retorno)
    desvio_cart.append(desvio)
    sharpe_index.append(sharpe)

# %% [markdown]
# # Criando um data frame com as informações de cada carteira aleatória gerada anteriormente;peso, retorno, desvio e o sharpe

# %%
dicionario={'Retorno':retorno_cart,'Desvio Padrão': desvio_cart,'Sharpe': sharpe_index}

# %%
for counter,ticker in enumerate(tickers):
    dicionario[ticker + ' peso'] = [peso[counter] for peso in peso_acoes]
    carteira2 = pd.DataFrame(dicionario)

carteira2
# Out:
#         Retorno  Desvio Padrão    Sharpe  ABEV3 peso  ITUB3 peso  GGBR3 peso  \
# 0      0.010148       0.181441 -0.002488    0.436849   -0.952012    0.175887
# 1      0.018374       0.171314  0.045381    0.481075    0.222779    0.452776
# 2      0.021946       0.077155  0.147060   -0.089669   -0.240482   -0.049077
# 3      0.015484       0.069381  0.070387    0.106419    0.204809   -0.207217
# 4      0.019560       0.125262  0.071530   -0.183683    0.301462   -0.297324
# ...         ...            ...       ...         ...         ...         ...
# 99995  0.020601       0.101687  0.098353    0.064876    0.400700   -0.073673
# 99996  0.017336       0.078790  0.085488    0.090944   -0.166972   -0.138710
# 99997  0.001064       0.251437 -0.037925   -0.117268   -0.977756    1.052012
# 99998  0.014351       0.119099  0.031498   -0.033917    0.365120    0.074704
# 99999  0.038715       0.285860  0.098352    0.984473    1.102126    0.692161
#
#        LREN3 peso  VALE3 peso  IBOV peso  BBDC3 peso  FLRY3 peso  VIIA3 peso  \
# 0       -0.025504   -0.481694   0.370163   -0.162524   -0.773483    0.700239
# 1       -0.383162    0.137799  -0.345214    0.352460   -0.046416    0.485752
# 2        0.247022    0.198103  -0.079233   -0.198190    0.047007    0.014126
# 3        0.084491   -0.230469   0.240951    0.008000    0.145877   -0.231499
# 4       -0.287375    0.400188   0.661733   -0.603486   -0.259322    0.147623
# ...           ...         ...        ...         ...         ...         ...
# 99995   -0.324630    0.144562  -0.367824    0.273609    0.051818    0.365266
# 99996   -0.112691    0.123279   0.053311    0.208238    0.121240    0.162666
# 99997    0.030092   -0.563016   0.573630   -0.411998   -0.006827    0.969873
# 99998   -0.511942    0.072248  -0.288026    0.101076    0.274791   -0.505062
# 99999   -1.485458   -0.272343  -1.176752   -0.185040    0.007911   -0.565556
#
#        RENT3 peso  IGTA3 peso  MGLU3 peso  EMBR3 peso  OZ1D peso  \
# 0        0.651995   -0.040435   -0.349647    0.018343   1.041939
# 1        0.355281    0.035850   -0.163391   -0.586011   0.331112
# 2       -0.091863    0.042572    0.319367    0.211210   0.352034
# 3        0.232273   -0.057702    0.216922    0.191541   0.174218
# 4       -0.196320    0.671448    0.384456    0.217035   0.669645
# ...           ...         ...         ...         ...        ...
# 99995    0.250637    0.091533    0.006173   -0.361145   0.301928
# 99996    0.193865    0.220452    0.078311    0.131065   0.223529
# 99997    0.393899    0.019751   -0.781147    0.366523   0.475544
# 99998    0.241285    0.165184    0.222619    0.538176  -0.175859
# 99999   -0.570032    1.259095    1.364633    0.319654   0.767858
#
#        DOLAR AMERICANO peso
# 0                  0.389884
# 1                 -0.330692
# 2                  0.317071
# 3                  0.121385
# 4                 -0.626079
# ...                     ...
# 99995              0.176170
# 99996             -0.188529
# 99997             -0.023312
# 99998              0.459604
# 99999             -1.242729
#
# [100000 rows x 18 columns]

# %% [markdown]
# # Plotando o sharpe de todas as carteiras simuladas em gráfico de retorno por desvio padrão

# %%
carteira2.plot.scatter(x='Desvio Padrão', y='Retorno', c='Sharpe', figsize=(16,8), grid = True, cmap='RdYlGn', edgecolors= 'black', xlim=(0,0.2), ylim=(-0.05,0.05))

# %% [markdown]
# # Localizando a carteira com maior sharpe

# %%
maior_sharpe= carteira2['Sharpe'].max()
carteira_maior_sharpe=carteira2.loc[carteira2['Sharpe']==maior_sharpe]
#aqui pegamos a matriz transposta para ter uma melhor vizualização dos dados
print(f'carteira com maior sharpe: {carteira_maior_sharpe.T}')
# Out:
# carteira com maior sharpe:                          73277
# Retorno               0.042005
# Desvio Padrão         0.127649
# Sharpe                0.246025
# ABEV3 peso            0.030565
# ITUB3 peso            0.340952
# GGBR3 peso           -0.358353
# LREN3 peso            0.222297
# VALE3 peso            0.344799
# IBOV peso            -0.805579
# BBDC3 peso            0.277789
# FLRY3 peso           -0.666344
# VIIA3 peso            0.169136
# RENT3 peso            0.560126
# IGTA3 peso           -0.775348
# MGLU3 peso            0.490533
# EMBR3 peso            0.577363
# OZ1D peso             0.388013
# DOLAR AMERICANO peso  0.204052

# %% [markdown]
# # Criando a função de otimização, de soma dos pesos e encontrando a carteira otima a partir da biblioteca optimize

# %%
def otimizacao(peso, retorno_mesnsal_esperado, cov_carteira, rf):
    #primeiro calculamos o retorno da carteira multiplicando a matriz do peso pela matriz dos retornos esperados
    retorno= np.dot(peso, retorno_mensal_esperado)
    #segundo passo é calcular o desvio padrão da carteira, para isso multiplicamos a matriz de pesos pela matriz de covariãncias e multiplicamos esse resultado pela matriz transposta do peso
    desvio=np.sqrt(np.matmul(peso.T, np.matmul(peso,np.array(cov_carteira))))
    #por fim calculamos o sharpe já considerando o ativo livre de riscos rf
    sharpe=-(retorno-rf)/desvio
    
    return sharpe

def soma_pesos(peso):
    soma=1
    soma=soma - np.sum(peso)
    return soma

restricao= {'type': 'eq', 'fun': soma_pesos}
start= np.random.random(num_acoes)
args= (retorno_mensal_esperado, cov_carteira, rf)
result= op.minimize(otimizacao, start, args=args, constraints=restricao)
pesos= result.x
carteiraOtima= pd.DataFrame({'Ativos': tickers, 'Pesos': pesos})
carteiraOtima.set_index(['Ativos'],inplace=True)
carteiraOtima
# Out:
#                        Pesos
# Ativos
# ABEV3           -1383.568372
# ITUB3            -358.928258
# GGBR3             -66.979217
# LREN3             392.181252
# VALE3             199.652539
# IBOV            -2934.999135
# BBDC3            -299.436653
# FLRY3           -1550.628125
# VIIA3            1506.563176
# RENT3            2752.235022
# IGTA3           -1527.940751
# MGLU3            4069.330150
# EMBR3             213.719114
# OZ1D             -605.694701
# DOLAR AMERICANO  -404.506041

# %%
#calculando o retorno da carteira multiplicando a matriz peso pela matriz dos retornos esperados
retorno_p= np.dot(pesos, retorno_mensal_esperado)
#calculando o desvio padrão da carteira multiplicando a matriz de pesos pela matriz de covariância e multiplicando esse resultado pela matriz transposta do peso
desvio_p= np.sqrt(np.matmul(pesos.T, np.matmul(pesos, np.array(cov_carteira))))
#calculando o índice de sharpe
sharpe_p= (retorno_p-rf)/desvio_p
pd.DataFrame([retorno_p, desvio_p, sharpe_p], ['E[r]', 'Risco','Sharpe'], ['carteira de ativos de risco otima'])
# Out:
#         carteira de ativos de risco otima
# E[r]                           206.526972
# Risco                          912.043139
# Sharpe                           0.226433

# %% [markdown]
# # Construindo a LAC

# %%
fim= max(carteira2['Desvio Padrão'])
x= np.linspace(0,fim,num_sim)
lac= sharpe_p*x + rf
plt.figure(num="Grafico de retorno por desvio padrão", figsize = (16,8), dpi=80)
plt.scatter(x=carteira2['Desvio Padrão'], y=carteira2['Retorno'], c=carteira2['Sharpe'], s=20, cmap='RdYlGn', edgecolors='black' )
#plt.scatter(x=carteira_sharpe['Desvio Padrão'], y=carteira_sharpe['Retorno'], s=50, edgecolors='black', label='Carteira Otima Otimização')      
plt.scatter(x=desvio_p, y=retorno_p, s=50,edgecolors='black', label='Carteira Otima Otimização')
plt.plot(x,lac,label='LAC')
plt.ylim((-0.12,400))
plt.xlim((0,1000))
#plt.yticks(carteira_sharpe['Retorno'])
#plt.xticks(carteira_sharpe['Desvio Padrão'])
#plt.grid()
plt.legend()

# %% [markdown]
# # Criando a função utilidade e plotando o gráfico de cada perfil de investidor junto com a LAC

# %%
def retorno_utilidade_investidor(A, U):
    sigma= np.linspace(0,max(carteira2['Desvio Padrão']), num_sim)
    retorno= 0.5*A*sigma**2 + U
    return retorno

# %%
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
U=0.05
plt.plot(x, retorno_utilidade_investidor(20,U), label='Utilidade Conservador')
plt.plot(x, retorno_utilidade_investidor(10,U), label='Utilidade Moderado')
plt.plot(x, retorno_utilidade_investidor(5,U), label='Utilidade Agressivo')
plt.plot(x,lac,label='LAC')
plt.legend()

# %%
def CPO(A):
    y= (retorno_p-rf)/(A*desvio_p**2)
    retorno_c=y*retorno_p + (1-y)*rf
    desvio_c = ((y**2)*desvio_p**2)**(1/2)
    return retorno_c, desvio_c

def utilidade_investidor(A, retorno_c, desvio_c):
    utilidade_c= retorno_c - 0.5*A*desvio_c**2
    return utilidade_c

# %%
A=20
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Conservador')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((-0.5,1))
plt.xlim((-0.25,2))
plt.legend()

# %%
A=10
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Moderado')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((0,0.3))
plt.xlim((0,0.3))
plt.legend()

# %%
A=5
retorno_c, desvio_c= CPO(A)
utilidade_c= utilidade_investidor( A, retorno_c, desvio_c)
plt.figure(num='Gráfico de retorno por desvio padrão', figsize=(16,8), dpi=80)
plt.plot(x,lac, label='LAC')
#graf.plot(x,retorno_utilidade_investidor(A, utilidade_c), label='Utilidade aversão ao risco')
plt.scatter(x=desvio_c, y=retorno_c, s=50, edgecolors='black', label= 'Carteira Otima Otimização para o investidor Agressivo')
plt.yticks([retorno_c])
plt.xticks([desvio_c])
plt.grid()
plt.ylim((-0.25,0.5))
plt.xlim((-0.25,1))
plt.legend()
